# %%
from p01_run_forecast import main as p01_run_forecast
from p02_champion_challenger import main as p02_champion_challenger

# Running process 1
p01_run_forecast()

# Running process 2
p02_champion_challenger()
# Out:
# Folder '../run_results/run_20241121/' already exists.
# Folder '../run_results/latest/' already exists.
# 11:50:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:57 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\3283078\AppData\Local\anaconda3\Lib\site-packages\prophet\forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 11:50:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:59 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:02 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:02 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:02 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:03 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:03 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:03 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:03 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:04 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:04 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:04 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:04 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:04 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:04 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:05 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:05 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:05 - cmdstanpy - INFO - Chain [1] done processing
# 11:51:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:06 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\3283078\AppData\Local\anaconda3\Lib\site-packages\prophet\forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1064.149, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1059.301, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1055.049, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1063.470, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1047.609, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1048.979, Time=0.08 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1056.113, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1046.694, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1053.888, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1058.214, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1047.312, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1044.705, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1048.449, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1044.051, Time=0.08 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1041.563, Time=0.14 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1050.199, Time=0.14 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=1039.420, Time=0.15 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=1046.697, Time=0.14 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=1041.212, Time=0.20 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=inf, Time=0.40 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=0.19 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=1045.854, Time=0.22 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=inf, Time=0.49 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.38 sec
#
# Best model:  ARIMA(4,1,2)(0,0,0)[0]
# Total fit time: 3.977 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=0.73 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=749.666, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=746.994, Time=0.06 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=747.670, Time=0.09 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=746.999, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=748.475, Time=0.14 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=748.774, Time=0.15 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=747.301, Time=0.09 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.62 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=748.578, Time=0.03 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=748.460, Time=0.08 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=747.923, Time=0.13 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=747.379, Time=0.05 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=749.897, Time=0.19 sec
#  ARIMA(1,1,0)(1,1,0)[12] intercept   : AIC=748.975, Time=0.14 sec
#
# Best model:  ARIMA(1,1,0)(1,1,0)[12]
# Total fit time: 2.570 seconds

# %%
import pandas as pd
from config import run_settings

forecast = pd.read_csv(f'../run_results/latest/forecast/results.csv')
scores = pd.read_csv(f'../run_results/latest/scores/results.csv')
iteration_name = run_settings['run_name']


# Finding Best Score
scores["winner_model"] = scores.iloc[:,2:].idxmin(axis=1)
scores["winner_score"] =  scores.iloc[:,2:-1].min(axis=1)

# Adding Winenr to forecast
forecast = forecast.merge(scores[['label', 'winner_model']], how='left')
forecast["winner_forecast"] = forecast.apply(lambda row: row[row["winner_model"]] if pd.notnull(row["winner_model"]) else None, axis=1)

forecast = pd.read_csv(f'../run_results/{iteration_name}/forecast/results.csv')
forecast = pd.read_csv(f'../run_results/latest/forecast/results.csv')

scores = pd.read_csv(f'../run_results/{iteration_name}/scores/results.csv')
scores = pd.read_csv(f'../run_results/latest/scores/results.csv')

# %%
# Adding Winenr to forecast
forecast = forecast.merge(scores[['label', 'winner_model']], how='left')
forecast["winner_forecast"] = forecast.apply(lambda row: row[row["winner_model"]] if pd.notnull(row["winner_model"]) else None, axis=1)

# %%
forecast = pd.read_csv(f'../run_results/{iteration_name}/forecast/results.csv')
forecast = pd.read_csv(f'../run_results/latest/forecast/results.csv')

scores = pd.read_csv(f'../run_results/{iteration_name}/scores/results.csv')
scores = pd.read_csv(f'../run_results/latest/scores/results.csv')

# %%
scores
# Out:
#                  model_run_ts label  prophet  prophet_tuned     arima  \
# 0  2024-11-21 11:42:22.225497  type  0.07661       0.034075  0.139839
#
#      sarima  ensemble_prophet_prophet_tuned  ensemble_prophet_arima  \
# 0  0.084699                        0.052542                0.096066
#
#    ensemble_prophet_sarima  ensemble_prophet_tuned_arima  \
# 0                 0.059685                      0.079858
#
#    ensemble_prophet_tuned_sarima  ensemble_arima_sarima  \
# 0                       0.052424               0.109282
#
#    ensemble_prophet_prophet_tuned_arima  \
# 0                              0.073607
#
#    ensemble_prophet_prophet_tuned_sarima  ensemble_prophet_arima_sarima  \
# 0                               0.048861                       0.085233
#
#    ensemble_prophet_tuned_arima_sarima  \
# 0                             0.079421
#
#    ensemble_prophet_prophet_tuned_arima_sarima
# 0                                     0.069515

# %%
forecast
# Out:
#           Month  Passengers label                model_run_ts period  \
# 0    1949-01-31       112.0  type  2024-11-21 11:42:22.225497  TRAIN
# 1    1949-02-28       118.0  type  2024-11-21 11:42:22.225497  TRAIN
# 2    1949-03-31       132.0  type  2024-11-21 11:42:22.225497  TRAIN
# 3    1949-04-30       129.0  type  2024-11-21 11:42:22.225497  TRAIN
# 4    1949-05-31       121.0  type  2024-11-21 11:42:22.225497  TRAIN
# ..          ...         ...   ...                         ...    ...
# 169  1963-02-28         NaN  type  2024-11-21 11:42:22.225497   FCST
# 170  1963-03-31         NaN  type  2024-11-21 11:42:22.225497   FCST
# 171  1963-04-30         NaN  type  2024-11-21 11:42:22.225497   FCST
# 172  1963-05-31         NaN  type  2024-11-21 11:42:22.225497   FCST
# 173  1963-06-30         NaN  type  2024-11-21 11:42:22.225497   FCST
#
#         prophet  prophet_tuned       arima      sarima  \
# 0           NaN            NaN         NaN         NaN
# 1           NaN            NaN         NaN         NaN
# 2           NaN            NaN         NaN         NaN
# 3           NaN            NaN         NaN         NaN
# 4           NaN            NaN         NaN         NaN
# ..          ...            ...         ...         ...
# 169  529.275849     484.028635  488.551002  484.790732
# 170  568.636882     554.615736  488.510234  517.393518
# 171  562.691168     550.463907  488.578794  552.704709
# 172  570.697760     564.411123  488.693449  565.376241
# 173  608.534407     648.446001  488.794734  626.960029
#
#      ensemble_prophet_prophet_tuned  ensemble_prophet_arima  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
# ..                              ...                     ...
# 169                      506.652242              508.913425
# 170                      561.626309              528.573558
# 171                      556.577537              525.634981
# 172                      567.554441              529.695604
# 173                      628.490204              548.664570
#
#      ensemble_prophet_sarima  ensemble_prophet_tuned_arima  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
# ..                       ...                           ...
# 169               507.033290                    486.289818
# 170               543.015200                    521.562985
# 171               557.697938                    519.521350
# 172               568.037001                    526.552286
# 173               617.747218                    568.620368
#
#      ensemble_prophet_tuned_sarima  ensemble_arima_sarima  \
# 0                              NaN                    NaN
# 1                              NaN                    NaN
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
# ..                             ...                    ...
# 169                     484.409683             486.670867
# 170                     536.004627             502.951876
# 171                     551.584308             520.641751
# 172                     564.893682             527.034845
# 173                     637.703015             557.877381
#
#      ensemble_prophet_prophet_tuned_arima  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 169                            500.618495
# 170                            537.254284
# 171                            533.911290
# 172                            541.267444
# 173                            581.925047
#
#      ensemble_prophet_prophet_tuned_sarima  ensemble_prophet_arima_sarima  \
# 0                                      NaN                            NaN
# 1                                      NaN                            NaN
# 2                                      NaN                            NaN
# 3                                      NaN                            NaN
# 4                                      NaN                            NaN
# ..                                     ...                            ...
# 169                             499.365072                     500.872528
# 170                             546.882045                     524.846878
# 171                             555.286595                     534.658223
# 172                             566.828375                     541.589150
# 173                             627.980146                     574.763056
#
#      ensemble_prophet_tuned_arima_sarima  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 169                           485.790123
# 170                           520.173163
# 171                           530.582470
# 172                           539.493604
# 173                           588.066921
#
#      ensemble_prophet_prophet_tuned_arima_sarima
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 169                                   496.661554
# 170                                   532.289092
# 171                                   538.609644
# 172                                   547.294643
# 173                                   593.183793
#
# [174 rows x 20 columns]
